# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pyLDAvis 
pyLDAvis.enable_notebook()
# %matplotlib inline
import warnings 
warnings.filterwarnings("ignore")

# %%
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer 
from nltk.stem import SnowballStemmer
import string
import gensim 
from gensim import corpora
import nltk
#https://www.zhihu.com/question/34801598
#https://zhuanlan.zhihu.com/p/62414576
# %load 11.py  
#https://radimrehurek.com/gensim/models/ldamodel.html
#https://toutiao.io/posts/c7853u/preview
#https://nbviewer.jupyter.org/github/bmabey/pyLDAvis/blob/master/notebooks/pyLDAvis_overview.ipynb
#https://nbviewer.jupyter.org/github/bmabey/hacker_news_topic_modelling/blob/master/HN%20Topic%20Model%20Talk.ipynb#topic=0&lambda=1&term=

# %% [markdown]
# # build LDA

# %%
Lda_sgcm = gensim.models.ldamodel.LdaModel
Lda_scm = gensim.models.ldamodel.LdaModel
Lda_gcm = gensim.models.ldamodel.LdaModel

# %%
#dump and load

# %%
import json

# %%
with open("./doc_term_matrix_sgcm.txt", "r") as fp:
     doc_term_matrix_sgcm = json.load(fp)
with open("./doc_term_matrix_scm.txt", "r") as fp:
     doc_term_matrix_scm = json.load(fp)
with open("./doc_term_matrix_gcm.txt", "r") as fp:
     doc_term_matrix_gcm = json.load(fp)

# %%
dictionary_sgcm=gensim.corpora.dictionary.Dictionary.load('./dictionary_sgcm')
dictionary_scm=gensim.corpora.dictionary.Dictionary.load('./dictionary_scm')
dictionary_gcm=gensim.corpora.dictionary.Dictionary.load('./dictionary_gcm')

# %%
ldamodel_sgcm_7 = Lda_sgcm.load("./ldamodel_sgcm-7")
ldamodel_scm_7 = Lda_scm.load("./ldamodel_scm-7")
ldamodel_gcm_7 = Lda_gcm.load("./ldamodel_gcm-7")

# %% [markdown]
# # visualize topics

# %%
import warnings 
import pyLDAvis.gensim_models
warnings.filterwarnings('ignore') 
prepared_data_sgcm = pyLDAvis.gensim_models.prepare(ldamodel_sgcm_7,doc_term_matrix_sgcm, dictionary_sgcm)
prepared_data_scm = pyLDAvis.gensim_models.prepare(ldamodel_scm_7,doc_term_matrix_scm, dictionary_scm)
prepared_data_gcm = pyLDAvis.gensim_models.prepare(ldamodel_gcm_7,doc_term_matrix_gcm, dictionary_gcm)

# %%
prepared_data_sgcm
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 5     -0.107896 -0.062307       1        1  25.651047
# 0      0.132075 -0.119243       2        1  18.098639
# 1     -0.052482 -0.033617       3        1  14.347709
# 4      0.007515  0.092319       4        1  12.451394
# 2      0.047329  0.080290       5        1  11.356795
# 6     -0.088065 -0.001003       6        1  10.411620
# 3      0.061525  0.043560       7        1   7.682796, topic_info=              Term       Freq      Total Category  logprob  loglift
# 238           zero   3.000000   3.000000  Default  30.0000  30.0000
# 28         product  12.000000  12.000000  Default  29.0000  29.0000
# 208          green   4.000000   4.000000  Default  28.0000  28.0000
# 103    environment   4.000000   4.000000  Default  27.0000  27.0000
# 10        economic   4.000000   4.000000  Default  26.0000  26.0000
# ..             ...        ...        ...      ...      ...      ...
# 54      management   1.648095  15.966465   Topic7  -3.3735   0.2953
# 13   environmental   1.123700  17.329742   Topic7  -3.7565  -0.1696
# 145         impact   0.599302   3.386762   Topic7  -4.3852   0.8343
# 16         improve   0.599301   3.088106   Topic7  -4.3852   0.9266
# 245       supplier   0.599301   2.488588   Topic7  -4.3852   1.1425
#
# [351 rows x 6 columns], token_table=      Topic      Freq     Term
# term
# 155       2  0.727917  ability
# 42        1  0.665103  account
# 117       4  0.410445  achieve
# 117       5  0.410445  achieve
# 117       7  0.410445  achieve
# ...     ...       ...      ...
# 237       5  0.606769    waste
# 301       7  0.850158      way
# 80        1  0.695939    which
# 238       5  0.799871     zero
# 212       4  0.777281        þ
#
# [382 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[6, 1, 2, 5, 3, 7, 4])

# %%
prepared_data_scm
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 5     -0.153519  0.037934       1        1  49.601582
# 6      0.129586  0.091316       2        1  14.202545
# 0     -0.011517 -0.065961       3        1  13.840356
# 3      0.054067 -0.108424       4        1  11.499719
# 1     -0.031184  0.027947       5        1   6.407540
# 2     -0.000407  0.019338       6        1   4.404798
# 4      0.012974 -0.002149       7        1   0.043459, topic_info=             Term      Freq     Total Category  logprob  loglift
# 3           chain  8.000000  8.000000  Default  30.0000  30.0000
# 55    sustainable  3.000000  3.000000  Default  29.0000  29.0000
# 38         supply  8.000000  8.000000  Default  28.0000  28.0000
# 13  environmental  6.000000  6.000000  Default  27.0000  27.0000
# 65        process  3.000000  3.000000  Default  26.0000  26.0000
# ..            ...       ...       ...      ...      ...      ...
# 25          order  0.000681  1.323299   Topic7  -5.2417   0.1685
# 26   organization  0.000681  1.323299   Topic7  -5.2417   0.1685
# 27    procurement  0.000681  1.881315   Topic7  -5.2417  -0.1834
# 28        product  0.000681  3.334394   Topic7  -5.2417  -0.7557
# 29     production  0.000681  2.528226   Topic7  -5.2417  -0.4789
#
# [329 rows x 6 columns], token_table=      Topic      Freq         Term
# term
# 155       2  0.918459      ability
# 42        1  0.996372      account
# 117       4  0.963826      achieve
# 99        3  0.924236  acquisition
# 91        3  0.924236       across
# ...     ...       ...          ...
# 77        3  0.314280        taken
# 57        1  0.922887        three
# 116       3  0.609759          use
# 116       4  0.609759          use
# 141       4  0.963826       vision
#
# [164 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[6, 7, 1, 4, 2, 3, 5])

# %%
prepared_data_gcm
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0      0.060564 -0.074013       1        1  24.202472
# 2      0.059818  0.152673       2        1  19.370341
# 6     -0.154802  0.034825       3        1  18.229818
# 3      0.083246 -0.057734       4        1  16.625041
# 1     -0.081015 -0.064037       5        1   9.110408
# 4      0.065709  0.006418       6        1   8.782651
# 5     -0.033520  0.001868       7        1   3.679269, topic_info=           Term      Freq     Total Category  logprob  loglift
# 43      product  9.000000  9.000000  Default  30.0000  30.0000
# 36        green  4.000000  4.000000  Default  29.0000  29.0000
# 12   management  9.000000  9.000000  Default  28.0000  28.0000
# 80         zero  4.000000  4.000000  Default  27.0000  27.0000
# 53      process  3.000000  3.000000  Default  26.0000  26.0000
# ..          ...       ...       ...      ...      ...      ...
# 15    packaging  0.048181  1.347253   Topic7  -5.5294  -0.0284
# 16    principle  0.048181  1.905241   Topic7  -5.5294  -0.3749
# 17  procurement  0.048181  1.347253   Topic7  -5.5294  -0.0284
# 18          set  0.048181  2.041712   Topic7  -5.5294  -0.4441
# 19        whole  0.048181  2.073648   Topic7  -5.5294  -0.4596
#
# [321 rows x 6 columns], token_table=      Topic      Freq      Term
# term
# 20        1  0.480010   achieve
# 20        4  0.480010   achieve
# 0         2  0.742251    across
# 1         1  0.351914  activity
# 1         2  0.703827  activity
# ...     ...       ...       ...
# 163       1  0.720031       way
# 59        5  0.848114      well
# 19        2  0.964484     whole
# 80        2  0.940550      zero
# 40        6  0.884406         þ
#
# [229 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 3, 7, 4, 2, 5, 6])
